# %% [markdown]
# <a href="https://colab.research.google.com/github/nirajband/FMML_Projects_and-Labs/blob/main/UGMR_2023_Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-11 17:18:50--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  92.2MB/s    in 0.7s
#
# 2024-05-11 17:18:51 (92.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3106 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4584    1201.6583v1  This paper develops generalizations of empower...    cs
# 6507   1702.08651v1  We study the estimation of the latent variable...  stat
# 4454   1712.00368v1  Within a supervised classification framework, ...    cs
# 22472  1608.07494v3  We improve existing instability-based methods ...  stat
# 21714   1010.3320v2  The group lasso is a penalized regression meth...  stat
# ...             ...                                                ...   ...
# 4458   1712.02658v1  This paper proposes the adaptation of Support ...  stat
# 3828   1602.07776v4  We introduce recurrent neural network grammars...    cs
# 16383  1702.01466v1  Prepositions are highly polysemous, and their ...    cs
# 22777  1706.05612v2  The two-sample hypothesis testing problem is s...  stat
# 26754  1611.08050v2  We present an approach to efficiently detect t...    cs
#
#                                                    title  year  \
# 4584   Empowerment for Continuous Agent-Environment S...  2012
# 6507   Speeding Up Latent Variable Gaussian Graphical...  2017
# 4454   Hierarchical Bayesian image analysis: from low...  2017
# 22472  Estimating the Number of Clusters via Normaliz...  2016
# 21714  Exact block-wise optimization in group lasso a...  2010
# ...                                                  ...   ...
# 4458     Using SVDD in SimpleMKL for 3D-Shapes Filtering  2017
# 3828                   Recurrent Neural Network Grammars  2016
# 16383                            Prepositions in Context  2017
# 22777  Kernel Two-Sample Hypothesis Testing Using Ker...  2017
# 26754  Realtime Multi-Person 2D Pose Estimation using...  2016
#
#                                                 keywords
# 4584   [generalizations, empowerment, continuous, emp...
# 6507   [estimation, graphical, precision, superpositi...
# 4454   [supervised, classification, framework, classi...
# 22472  [instability, selection, normalizing, instabil...
# 21714  [penalized, regression, regression, covariates...
# ...                                                  ...
# 4458   [adaptation, description, simplemkl, introduce...
# 3828   [introduce, recurrent, probabilistic, sentence...
# 16383  [prepositions, polysemous, variegated, signifi...
# 22777  [hypothesis, challenging, dimensional, hypothe...
# 26754  [efficiently, nonparametric, representation, a...
#
# [4484 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4584     [generalizations, empowerment, continuous, emp...
# 6507     [estimation, graphical, precision, superpositi...
# 4454     [supervised, classification, framework, classi...
# 22472    [instability, selection, normalizing, instabil...
# 21714    [penalized, regression, regression, covariates...
#                                ...
# 19762    [inferring, inconsistency, decisions, separate...
# 1201     [including, successes, convolutional, recogniz...
# 14315    [estimating, clustering, structures, establish...
# 32359    [algorithms, approximate, inference, difficult...
# 19506    [similarity, reasoning, similarity, similarity...
# Name: keywords, Length: 5606, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8506 words.
# Out of those 4401 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9b3abb4b-bdcf-487d-9406-d06f39c025d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b3abb4b-bdcf-487d-9406-d06f39c025d7")) {                    Plotly.newPlot(                        "9b3abb4b-bdcf-487d-9406-d06f39c025d7",                        [{"x":["requiring","stochastic","curiosity","organisms","approximation","prediction","controllability","initially","observability","environment","theoretic","application","exploration","transition","important","generalization","biological","significantly","empowerment","influence","addressed","introduced","hypotheses","sensorimotor","transitions","information","considerations","intrinsic","efficiency","properties","regression","dimensionality","furthermore","continuous","processes","motivated","probabilities","forecasting","interesting","generalizations","superposition","estimator","algorithm","graphical","optimizations","demonstrate","constrained","precision","components","guaranteed","alternating","algorithms","magnitude","corroborate","efficient","likelihood","estimation","thresholding","nonconvex","synthetic","factorization","statistical","experiments","relaxation","superiority","variables","recovering","generally","classifier","objective","supervised","framework","estimated","unsupervised","reduction","incorporate","classification","clustering","simultaneously","homogeneous","parameters","techniques","statistically","hyperspectral","extraction","performance","preprocessing","exploiting","hierarchical","interpretation","normalized","available","sequences","selection","normalizing","estimating","instability","approximate","computational","computing","computation","penalized","coefficients","coefficient","theoretical","covariates","optimization","partitioned","demonstrating","simulations","univariate","projection","particular","foundation","dissimilarity","suggestions","randomized","generalize","straightforward","situations","definition","comparison","interpolate","developments","mentioned","developing","derivation","satisfies","distances","observation","structure","parametrized","generalized","applicability","concentration","probability","diffraction","spherical","topological","restricted","orientation","expectation","extension","associated","distribution","invariant","illustrated","considers","parameter","representation","specialized","symmetric","respectively","advantages","parameterized","distributions","maximization","establish","spherically","microscopy","morphable","relatively","independently","spatially","geometric","transform","occlusions","uncontrolled","convolutional","occlusion","localisation","normalisation","including","functions","interpret","transformer","inference","distributed","intractable","alternative","variational","approaches","analytically","resolution","modelling","simulation","filtering","observations","distributional","disciplines","challenging","reconstruct","wikileaks","propagation","implement","structured","smoothing","dimension","intensity","discretised"],"y":[46,120,3,6,112,212,2,17,5,99,48,201,56,36,273,91,43,232,2,57,28,106,29,4,14,607,11,41,131,209,93,55,158,97,98,56,56,24,53,9,7,26,744,43,11,479,53,72,95,30,28,512,53,2,353,59,173,14,16,103,39,135,537,15,28,127,24,53,119,139,162,527,55,105,86,54,464,120,86,13,211,357,21,12,111,755,25,64,94,52,22,260,92,143,1,59,4,122,277,114,128,3,42,17,166,2,268,7,26,46,6,38,264,12,10,5,25,52,18,36,32,126,3,24,18,53,6,18,44,48,299,3,60,31,10,174,2,8,14,49,24,31,80,92,186,50,18,25,90,329,25,25,72,74,14,99,30,35,1,12,3,54,36,22,77,67,9,5,321,22,6,4,200,199,20,5,199,90,25,84,47,403,8,79,42,63,55,71,18,12,226,32,1,69,65,105,19,57,29,0],"type":"bar"},{"x":["requiring","stochastic","curiosity","organisms","app ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4401,), (4401, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8511586452762924

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>Data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Augmentation</span> <span style=''>Approach</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>Deep</span> <span style=''>Models</span> <br/><br/><span style=''>Data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>augmentation</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>essential</span> <span style=''>part</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>process</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivation</span> <span style=''>is</span> <span style=''>that</span> <span style=''>a</span> <span style=''>robust</span> <span style=''>training</span> <span style=''>process</span> <span style=''>for</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538463);'>annotated</span> <span style=''>datasets</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>be</span> <span style=''>acquired</span> <span style=''>stored</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>processed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Therefore</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reasonable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>is</span> <span style=''>to</span> <span style=''>be</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.32110091743119257);'>automatically</span> <span style=''>generate</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538463);'>annotated</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>using</span> <span style=''>a</span> <span style=''>process</span> <span style=''>known</span> <span style=''>as</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>augmentation</span> <span style=''>The</span> <span style=''>dominant</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>augmentation</span> <span style=''>approach</span> <span style=''>in</span> <span style=''>the</span> <span style=''>field</span> <span style=''>assumes</span> <span style=''>that</span> <span style=''>new</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>via</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3391304347826087);'>geometric</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.9130434782608696);'>appearance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformations</span> <span style=''>applied</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538463);'>annotated</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>but</span> <span style=''>this</span> <span style=''>is</span> <span style=''>a</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>because</span> <span style=''>it</span> <span style=''>is</span> <span style=''>unclear</span> <span style=''>if</span> <span style=''>this< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>Real</span> <span style=''>Time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sentiment</span> <span style=''>Analysis</span> <span style=''>for</span> <span style=''>Big</span> <span style=''>Data</span> <span style=''>Social</span> <span style=''>Streams</span> <br/><br/><span style=''>Big</span> <span style=''>data</span> <span style=''>trend</span> <span style=''>has</span> <span style=''>enforced</span> <span style=''>the</span> <span style=''>data</span> <span style=''>centric</span> <span style=''>systems</span> <span style=''>to</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>fast</span> <span style=''>data</span> <span style=''>streams</span> <span style=''>In</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analytics</span> <span style=''>on</span> <span style=''>stream</span> <span style=''>data</span> <span style=''>has</span> <span style=''>formed</span> <span style=''>into</span> <span style=''>a</span> <span style=''>new</span> <span style=''>research</span> <span style=''>field</span> <span style=''>which</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>answer</span> <span style=''>queries</span> <span style=''>about</span> <span style=''>what</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>happening</span> <span style=''>now</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>negligible</span> <span style=''>delay</span> <span style=''>The</span> <span style=''>real</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>with</span> <span style=''>real</span> <span style=''>time</span> <span style=''>stream</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impossible</span> <span style=''>to</span> <span style=''>store</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>of</span> <span style=''>data</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>utilized</span> <span style=''>To</span> <span style=''>perform</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analytics</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>of</span> <span style=''>data</span> <span style=''>should</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>in</span> <span style=''>a</span> <span style=''>way</span> <span style=''>that</span> <span style=''>only</span> <span style=''>a</span> <span style=''>short</span> <span style=''>summary</span> <span style=''>of</span> <span style=''>stream</span> <span style=''>is</span> <span style=''>stored</span> <span style=''>in</span> <span style=''>main</span> <span style=''>memory</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>due</span> <span style=''>to</span> <span style=''>high</span> <span style=''>speed</span> <span style=''>of</span> <span style=''>arrival</span> <span style=''>average</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>time</span> <span style=''>for</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Continuation</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Mixing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Heterogenous</span> <span style=''>Sources</span> <br/><br/><span style=''>A</span> <span style=''>number</span> <span style=''>of</span> <span style=''>modern</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>involve</span> <span style='background-color:rgba(255, 0, 0, 0.33589251439539347);'>estimation</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>sources</span> <span style=''>This</span> <span style=''>includes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>with</span> <span style=''>labeled</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>other</span> <span style=''>problems</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analogous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>(game</span> <span style=''>theoretic)</span> <span style=''>problems</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style='background-color:rgba(255, 0, 0, 0.33589251439539347);'>estimation</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>reduced</span> <span style=''>to</span> <span style=''>solving</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>fixed</span> <span style=''>point</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>(consistency</span> <span style=''>conditions)</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>general</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combining</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preferred</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>source</span> <span style=''>with</span> <span style=''>another</span> <span style=''>in</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>by</span> <span style=''>evolving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>paths</span> <span style=''>of</span> <span style=''>fixed</span> <span style=''>points</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intermediate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>allocations</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicitly</span> <span style=''>identify</span> <span style=''>critical</span> <span style=''>points</span> <span style=''>along</span> <span style=''>the</span> <span style=''>unique</span> <span style=''>paths</span> <span style=''>to</span> <span style=''>either</span> <span style=''>increase</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3066666666666668);'>stability</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.33589251439539347);'>estimation</span> <span style=''>or</span> <span style=''>to</span> <span style=''>ensure</span> <span style=''>a</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>Training</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style=''>SVM</span> <br/><br/><span style=''>Training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>models</span> <span style=''>is</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>However</span> <span style=''>most</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>only</span> <span style=''>use</span> <span style=''>a</span> <span style=''>single</span> <span style=''>machine</span> <span style=''>thus</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>power</span> <span style=''>and</span> <span style=''>the</span> <span style=''>capacity</span> <span style=''>for</span> <span style=''>larger</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>machines</span> <span style=''>have</span> <span style=''>not</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploited</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>distributedly</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>block</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinate</span> <span style=''>descent</span> <span style=''>method</span> <span style=''>Both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>results</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12215909090909091)
# 	segmentation (0.06696428571428571)
# 	experimental (0.1367694805194805)
# 	architecture (0.09090909090909091)
# 	representation (0.13352272727272727)
# 	detection (0.11607142857142858)
# 	information (0.2463474025974026)
# 	convolutional (0.13027597402597402)
# 	different (0.2609577922077922)
# 	recognition (0.13433441558441558)
#
# Some Statistics words are:
# 	variables (0.1306930693069307)
# 	algorithms (0.29108910891089107)
# 	theoretical (0.15148514851485148)
# 	statistical (0.1405940594059406)
# 	algorithm (0.3940594059405941)
# 	estimation (0.17227722772277226)
# 	inference (0.18366336633663366)
# 	distribution (0.18415841584158416)
# 	dimensional (0.1915841584158416)
# 	regression (0.17227722772277226)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="727c6226-8af6-498e-a742-27aecfeee279" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("727c6226-8af6-498e-a742-27aecfeee279")) {                    Plotly.newPlot(                        "727c6226-8af6-498e-a742-27aecfeee279",                        [{"x":["requiring","stochastic","curiosity","organisms","approximation","prediction","controllability","initially","observability","environment","theoretic","application","exploration","transition","important","generalization","biological","significantly","empowerment","influence","addressed","introduced","hypotheses","sensorimotor","transitions","information","considerations","intrinsic","efficiency","properties","regression","dimensionality","furthermore","continuous","processes","motivated","probabilities","forecasting","interesting","generalizations","superposition","estimator","algorithm","graphical","optimizations","demonstrate","constrained","precision","components","guaranteed","alternating","algorithms","magnitude","corroborate","efficient","likelihood","estimation","thresholding","nonconvex","synthetic","factorization","statistical","experiments","relaxation","superiority","variables","recovering","generally","classifier","objective","supervised","framework","estimated","unsupervised","reduction","incorporate","classification","clustering","simultaneously","homogeneous","parameters","techniques","statistically","hyperspectral","extraction","performance","preprocessing","exploiting","hierarchical","interpretation","normalized","available","sequences","selection","normalizing","estimating","instability","approximate","computational","computing","computation","penalized","coefficients","coefficient","theoretical","covariates","optimization","partitioned","demonstrating","simulations","univariate","projection","particular","foundation","dissimilarity","suggestions","randomized","generalize","straightforward","situations","definition","comparison","interpolate","developments","mentioned","developing","derivation","satisfies","distances","observation","structure","parametrized","generalized","applicability","concentration","probability","diffraction","spherical","topological","restricted","orientation","expectation","extension","associated","distribution","invariant","illustrated","considers","parameter","representation","specialized","symmetric","respectively","advantages","parameterized","distributions","maximization","establish","spherically","microscopy","morphable","relatively","independently","spatially","geometric","transform","occlusions","uncontrolled","convolutional","occlusion","localisation","normalisation","including","functions","interpret","transformer","inference","distributed","intractable","alternative","variational","approaches","analytically","resolution","modelling","simulation","filtering","observations","distributional","disciplines","challenging","reconstruct","wikileaks","propagation","implement","structured","smoothing","dimension","intensity","discretised","flexibility","importance","scalability","different","constraints","similarity","interactive","effectiveness","autocorrelation","relational","adversarial","character","opposites","vulnerable","recognize","completely","adversary","applications","modifications","recognition","logarithmic","calibration","conditional","ingredients","increasingly","inequality","corresponding","asymmetric","translates","increases","employing","typically","prototype","candidate","challenge","selecting","annotation","carefully","significant","industrial","achieving","presented","crowdsourcing","potential","management","methodology","instances","generating","efficiently","addressing","especially","platforms","collecte ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	discretised
# 	autocorrelation
# 	functoriality
# 	kleinberg
# 	disaggregate
# 	disaggregation
# 	particulars
# 	initialising
# 	initialise
# 	covariate
# 	discretisation
# 	unavoidably
# 	contractions
# 	deletions
# 	injecting
# 	unregularized
# 	sociology
# 	homoscedastic
# 	distributionally
# 	expectimax
# Some words which never appear in Statistics papers:
# 	curiosity
# 	controllability
# 	sensorimotor
# 	morphable
# 	occlusions
# 	localisation
# 	transformer
# 	ambiguous
# 	accumulate
# 	inaccuracies
# 	navigating
# 	linguists
# 	infrastructure
# 	compensates
# 	connectionist
# 	achromatic
# 	untrimmed
# 	activitynet
# 	attribution
# 	portuguese

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.4434075961571576e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8324420677361853
